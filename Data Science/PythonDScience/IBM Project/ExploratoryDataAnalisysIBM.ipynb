# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Objectives
#
# <ul>
#     <li>Explore features or characteristics to precit price of car</li>
# </ul>

# %% [markdown]
# ## Table of Contents
#
# <ol>
#     <li>Import Libraries</li>
#     <li>Analyzing Individual Feature Patterns Using Visualization</li>
#     <li>Descriptive Statistical Analysis</li>
#     <li>Basics of Grouping</li>
#     <li>Correlation and Causation</li>
#     <li>ANOVA</li>
# </ol>

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import scipy as sc
import seaborn as sns
import skillsnetwork as sk

# %%
data = 'clean_df.csv'
df = pd.read_csv(data, index_col=0)
df.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  city-mpg  \
# 0          rwd           front        88.6  0.811148  0.890278  ...        21
# 1          rwd           front        88.6  0.811148  0.890278  ...        21
# 2          rwd           front        94.5  0.822681  0.909722  ...        19
# 3          fwd           front        99.8  0.848630  0.919444  ...        24
# 4          4wd           front        99.4  0.848630  0.922222  ...        18
#
# ...

# %% [markdown]
# ### Analyzing Individual Feature Patterns Using Visualization

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 200
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   num-of-doors       201 non-null    object
#  4   body-style         201 non-null    object
#  5   drive-wheels       201 non-null    object
#  6   engine-location    201 non-null    object
#  7   wheel-base         201 non-null    float64
#  8   length             201 non-null    float64
#  9   width              201 non-null    float64
#  10  height             201 non-null    float64
#  11  curb-weight        201 non-null    int64
#  12  engine-type        201 non-null    object
#  13  num-of-cylinders   201 non-null    object
#  14  engine-size        201 non-null    int64
#  15  fuel-system        201 non-null    object
# ...

# %%
df_corr = df.corr(numeric_only=True)
plt.figure(figsize=(10,6))
heatmap = sns.heatmap(df_corr, annot=False, cmap='coolwarm', linewidths=.5)
heatmap.set_title('Heatmap Correlation Data Frame')
plt.show()

# %% [markdown]
# #### Continuous Numerical Variables

# %% [markdown]
# ##### Positive Linear Relationship

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='highway-L/100km', y='price', data=df)
print(df[['highway-L/100km','price']].corr())
# Out:
#                  highway-L/100km     price
# highway-L/100km         1.000000  0.801118
# price                   0.801118  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='city-L/100km', y='price', data=df)
print(df[['city-L/100km','price']].corr())
# Out:
#               city-L/100km     price
# city-L/100km      1.000000  0.789898
# price             0.789898  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='horsepower', y='price', data=df)
print(df[['horsepower','price']].corr())
# Out:
#             horsepower     price
# horsepower    1.000000  0.809607
# price         0.809607  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='engine-size', y='price', data=df)
print(df[['engine-size','price']].corr())
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='curb-weight', y='price', data=df)
print(df[['curb-weight','price']].corr())
# Out:
#              curb-weight     price
# curb-weight     1.000000  0.834415
# price           0.834415  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='width', y='price', data=df)
print(df[['width','price']].corr())
# Out:
#           width     price
# width  1.000000  0.751265
# price  0.751265  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='length', y='price', data=df)
print(df[['length','price']].corr())
# Out:
#           length     price
# length  1.000000  0.690628
# price   0.690628  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='bore', y='price', data=df)
print(df[['bore','price']].corr())
# Out:
#            bore     price
# bore   1.000000  0.543155
# price  0.543155  1.000000

# %% [markdown]
# ##### Weak Linear Relationship

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='peak-rpm', y='price', data=df)
print(df[['peak-rpm','price']].corr())
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101612
# price    -0.101612  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='aspiration-std', y='price', data=df)
df[['aspiration-std','price']].corr()
# Out:
#                 aspiration-std     price
# aspiration-std        1.000000 -0.179578
# price                -0.179578  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='normalized-losses', y='price', data=df)
print(df[['normalized-losses','price']].corr())
# Out:
#                    normalized-losses     price
# normalized-losses           1.000000  0.133999
# price                       0.133999  1.000000

# %%
plt.figure(figsize=(6,4))
sns.regplot(x='highway-mpg', y='price', data=df)
print(df[['highway-mpg','price']].corr())
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# ##### Categorical Variables

# %% [markdown]
# ##### Boxplot visualization

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='make', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='num-of-doors', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='body-style', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='engine-location', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='drive-wheels', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='engine-type', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='num-of-cylinders', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='fuel-system', y='price', data =df )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Descriptive Statistical Analysis

# %%
df.describe(include='all')
# Out:
#          symboling  normalized-losses    make num-of-doors body-style  \
# count   201.000000          201.00000     201          201        201
# unique         NaN                NaN      22            2          5
# top            NaN                NaN  toyota         four      sedan
# freq           NaN                NaN      32          115         94
# mean      0.840796          122.00000     NaN          NaN        NaN
# std       1.254802           31.99625     NaN          NaN        NaN
# min      -2.000000           65.00000     NaN          NaN        NaN
# 25%       0.000000          101.00000     NaN          NaN        NaN
# 50%       1.000000          122.00000     NaN          NaN        NaN
# 75%       2.000000          137.00000     NaN          NaN        NaN
# max       3.000000          256.00000     NaN          NaN        NaN
#
#        drive-wheels engine-location  wheel-base      length       width  ...  \
# ...

# %%
#Value Counts
make_counts = df['make'].value_counts().to_frame()
make_counts.rename(columns={'count':'value_counts'},inplace=True)
make_counts.index.name = 'make'
make_counts
# Out:
#                value_counts
# make
# toyota                   32
# nissan                   18
# mazda                    17
# mitsubishi               13
# honda                    13
# volkswagen               12
# subaru                   12
# peugot                   11
# volvo                    11
# dodge                     9
# mercedes-benz             8
# bmw                       8
# plymouth                  7
# audi                      6
# saab                      6
# porsche                   4
# jaguar                    3
# chevrolet                 3
# alfa-romero               3
# isuzu                     2
# renault                   2
# mercury                   1

# %%
ndoors_counts = df['num-of-doors'].value_counts().to_frame()
ndoors_counts.rename(columns={'count':'value_counts'},inplace=True)
ndoors_counts.index.name = 'num_of_doors'
ndoors_counts
# Out:
#               value_counts
# num_of_doors
# four                   115
# two                     86

# %%
body_style_counts = df['body-style'].value_counts().to_frame()
body_style_counts.rename(columns={'count':'value_counts'},inplace=True)
body_style_counts.index.name = 'body-style'
body_style_counts
# Out:
#              value_counts
# body-style
# sedan                  94
# hatchback              68
# wagon                  25
# hardtop                 8
# convertible             6

# %%
eloc_counts = df['engine-location'].value_counts().to_frame()
eloc_counts.rename(columns={'count':'value_counts'},inplace=True)
eloc_counts.index.name = 'engine-location'
eloc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
hpb_counts = df['horsepower-binned'].value_counts().to_frame()
hpb_counts.rename(columns={'count':'value_counts'},inplace=True)
hpb_counts.index.name = 'horsepower-binned'
hpb_counts
# Out:
#                    value_counts
# horsepower-binned
# Low                         153
# Medium                       43
# High                          5

# %%
dw_counts = df['drive-wheels'].value_counts().to_frame()
dw_counts.rename(columns={'count':'value_counts'},inplace=True)
dw_counts.index.name = 'drive-wheels'
dw_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %% [markdown]
# #### Grouping

# %%
df_group_one = df[['make','price']]
df_group_one = df_group_one.groupby(['make'], as_index=False).mean()
df_group_one =  df_group_one.sort_values(by='price',ascending=False).round(2)
df_group_one
# Out:
#              make     price
# 7          jaguar  34600.00
# 9   mercedes-benz  33647.00
# 15        porsche  31400.50
# 2             bmw  26118.75
# 21          volvo  18063.18
# 1            audi  17859.17
# 10        mercury  16503.00
# 0     alfa-romero  15498.33
# 13         peugot  15489.09
# 17           saab  15223.33
# 8           mazda  10652.88
# 12         nissan  10415.67
# 20     volkswagen  10077.50
# 19         toyota   9885.81
# 16        renault   9595.00
# 11     mitsubishi   9239.77
# 6           isuzu   8916.50
# 18         subaru   8541.25
# 5           honda   8184.69
# 14       plymouth   7963.43
# 4           dodge   7875.44
# 3       chevrolet   6007.00

# %%
df_group_two = df[['num-of-doors','price']]
df_group_two = df_group_two.groupby(['num-of-doors'], as_index=False).mean()
df_group_two = df_group_two.sort_values(by='price',ascending=False).round(2)
df_group_two
# Out:
#   num-of-doors     price
# 0         four  13498.03
# 1          two  12818.13

# %%
df_group_three = df[['body-style','price']]
df_group_three = df_group_three.groupby(['body-style'], as_index=False).mean()
df_group_three = df_group_three.sort_values(by='price', ascending=False).round(2)
df_group_three
# Out:
#     body-style     price
# 1      hardtop  22208.50
# 0  convertible  21890.50
# 3        sedan  14459.76
# 4        wagon  12371.96
# 2    hatchback   9957.44

# %%
df_group_four = df[['engine-location','price']]
df_group_four = df_group_four.groupby(['engine-location'], as_index=False).mean()
df_group_four = df_group_four.sort_values(by='price', ascending=False).round(2)
df_group_four
# Out:
#   engine-location     price
# 1            rear  34528.00
# 0           front  12884.09

# %%
df_group_five = df[['horsepower-binned','price']]
df_group_five = df_group_five.groupby(['horsepower-binned'], as_index=False).mean()
df_group_five = df_group_five.sort_values(by='price', ascending=False).round(2)
df_group_five
# Out:
#   horsepower-binned     price
# 0              High  31856.60
# 2            Medium  22486.47
# 1               Low   9989.75

# %%
df_group_six = df[['drive-wheels','price']]
df_group_six = df_group_six.groupby(['drive-wheels'], as_index=False).mean()
df_group_six = df_group_six.sort_values(by='price', ascending=False).round(2)
df_group_six
# Out:
#   drive-wheels     price
# 2          rwd  19757.61
# 0          4wd  10241.00
# 1          fwd   9244.78

# %%
df_gptest = df[['body-style','drive-wheels','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'], as_index=False).mean().round(2)
grouped_pivot1 = grouped_test1.pivot(index='drive-wheels', columns='body-style')
grouped_pivot1
# Out:
#                    price
# body-style   convertible   hardtop hatchback     sedan     wagon
# drive-wheels
# 4wd                  NaN       NaN   7603.00  12647.33   9095.75
# fwd              11595.0   8249.00   8396.39   9811.80   9997.33
# rwd              23949.6  24202.71  14337.78  21711.83  16994.22

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot1, cmap='RdBu')

row_labels = grouped_pivot1.columns.levels[1]
col_labels = grouped_pivot1.index

ax.set_xticks(np.arange(grouped_pivot1.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot1.shape[0]) + 0.5, minor=False)

ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()
# Out:
# C:\Users\herre\AppData\Local\Temp\ipykernel_15216\3048203573.py:15: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   fig.colorbar(im)

# %%
df_gptest2 = df[['body-style','engine-location','price']]
grouped_test2 = df_gptest2.groupby(['engine-location','body-style'], as_index=False).mean().round(2)
grouped_pivot2 = grouped_test2.pivot(index='engine-location', columns='body-style')
grouped_pivot2
# Out:
#                       price
# body-style      convertible   hardtop hatchback     sedan     wagon
# engine-location
# front               18863.0  18518.67   9957.44  14459.76  12371.96
# rear                37028.0  33278.00       NaN       NaN       NaN

# %%
fig, ax = plt.subplots()

im_2 = ax.pcolor(grouped_pivot2, cmap='RdBu')

row_labels2 = grouped_pivot2.columns.levels[1]
col_labels2 = grouped_pivot2.index

ax.set_xticks(np.arange(grouped_pivot2.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot2.shape[0]) + 0.5, minor=False)

ax.set_xticklabels(row_labels2, minor=False)
ax.set_yticklabels(col_labels2, minor=False)

plt.xticks(rotation=90)
fig.colorbar(im_2)
plt.show()
# Out:
# C:\Users\herre\AppData\Local\Temp\ipykernel_15216\3995806624.py:15: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   fig.colorbar(im_2)

# %%
df_gptest3 = df[['horsepower-binned','engine-location','price']]
grouped_test3 = df_gptest3.groupby(['engine-location','horsepower-binned'], as_index=False).mean().round(2)
grouped_pivot3 = grouped_test3.pivot(index='engine-location', columns='horsepower-binned')
grouped_pivot3
# Out:
#                      price
# horsepower-binned     High      Low    Medium
# engine-location
# front              27849.5  9989.75  22486.47
# rear               34528.0      NaN       NaN

# %%
fig, ax = plt.subplots()

im_3 = ax.pcolor(grouped_pivot3, cmap='RdBu')

row_labels3 = grouped_pivot3.columns.levels[1]
col_labels3 = grouped_pivot3.index

ax.set_xticks(np.arange(grouped_pivot3.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot3.shape[0]) + 0.5, minor=False)

ax.set_xticklabels(row_labels3, minor=False)
ax.set_yticklabels(col_labels3, minor=False)

plt.xticks(rotation=90)

fig.colorbar(im_3)

plt.show()
# Out:
# C:\Users\herre\AppData\Local\Temp\ipykernel_15216\158754775.py:16: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   fig.colorbar(im_3)

# %% [markdown]
# #### Correlation and Causation

# %% [markdown]
# #### Pearson Correlation
#
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li>1: perfect positive correlation</li>
#     <li>0: no linear correlation, thw two variables most likely do not affect each other</li>
#     <li>-1: Perfect negative lienar correlation</li>
# </ul>

# %%
df_corr
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.175352          -0.115998    0.251693  0.163569
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %% [markdown]
# #### P-Value
# <p>P-Value es the probability value that the correlation between these two variables is statistically significant.
# Normally, we choose a significance level of 0.005, which means that are 95% confident that the correlation between the variables is significant</p>
#
# <ul>
#     <li>p-value is < 0.001: there is a strong evidence that the correlation is significant.</li>
#     <li>p-value is < 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>p-value is < 0.01: there is a weak evidence that the correlation is significant.</li>
#     <li>p-value is > 0.1: there is no evidence that the correltion is significant.</li>
# </ul>

# %%
from scipy import stats

# %%
#Correlation and P-value by normalized-losses
pearson_coef_nl, p_value_nl = stats.pearsonr(df['normalized-losses'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_nl, 'with a P-vavlue of P = ', p_value_nl)
# Out:
# The Pearson Correlation Coefficient is:  0.13399873429274337 with a P-vavlue of P =  0.05789749352703129

# %% [markdown]
# <p>since the pearson coefficiente is (~0.1339) the linear relationship is weak, and since the p-value is (~0.05) there is a moderate evidence in statistically significance</p>

# %%
#Correlation and P-value by wheel-base 
pearson_coef_wb, p_value_wb = stats.pearsonr(df['wheel-base'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_wb, 'with a P-vavlue of P = ', p_value_wb)
# Out:
# The Pearson Correlation Coefficient is:  0.584641822265508 with a P-vavlue of P =  8.076488270732947e-20

# %% [markdown]
# <p>since the pearson coefficient is (~0.5846) the linear relationship is moderate, and since the p-value is < 0,001 there is a strong statistically significance</p>

# %%
#Correlation and p-value by length
pearson_coef_length, p_value_length = stats.pearsonr(df['length'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_length, 'with a P-vavlue of P = ', p_value_length)
# Out:
# The Pearson Correlation Coefficient is:  0.6906283804483639 with a P-vavlue of P =  8.016477466159153e-30

# %% [markdown]
# <p>since the pearson coefficient is (~0.6906) the linear relationship is moderate, and since the p-value is < 0,001 there is a strong statistically significance</p>

# %%
#Correlation and p-value by width
pearson_coef_width, p_value_width = stats.pearsonr(df['width'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_width, 'with a P-vavlue of P = ', p_value_width)
# Out:
# The Pearson Correlation Coefficient is:  0.7512653440522673 with a P-vavlue of P =  9.200335510482065e-38

# %% [markdown]
# <p>since the pearson coefficient is (~0.7512) the linear relationship is quite strong, and since the p-value is < 0,001 there is a strong statistically significance </p>

# %%
#Correlation and p-value by height
pearson_coef_height, p_value_height = stats.pearsonr(df['height'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_height, 'with a P-vavlue of P = ', p_value_height)
# Out:
# The Pearson Correlation Coefficient is:  0.1354863075680599 with a P-vavlue of P =  0.055146273251012276

# %% [markdown]
# <p>since the pearson coefficient is (~0.1354) the linear relationship is weak, and since the p-value is aprox.  0,05 there is a moderate statistically significance </p>

# %%
#Correlation and p-value by curb-weight
pearson_coef_cw, p_value_cw = stats.pearsonr(df['curb-weight'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_cw, 'with a P-vavlue of P = ', p_value_cw)
# Out:
# The Pearson Correlation Coefficient is:  0.8344145257702843 with a P-vavlue of P =  2.189577238893972e-53

# %% [markdown]
# <p>since the pearson coefficient is (~0.8344) the linear relationship is quite strong, and since the p-value is < 0,001 there is a strong statistically significance </p>

# %%
#Correlation and p-value by engine-size
pearson_coef_es, p_value_es = stats.pearsonr(df['engine-size'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_es, 'with a P-vavlue of P = ', p_value_es)
# Out:
# The Pearson Correlation Coefficient is:  0.8723351674455182 with a P-vavlue of P =  9.265491622200262e-64

# %% [markdown]
# <p>since the pearson coefficient is (~0.8723) the linear relationship is quite strong, and since the p-value is < 0,001 there is a strong statistically significance </p>

# %%
#Correlation and p-value by bore
pearson_coef_b, p_value_b = stats.pearsonr(df['bore'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_b, 'with a P-vavlue of P = ', p_value_b)
# Out:
# The Pearson Correlation Coefficient is:  0.5431553832626603 with a P-vavlue of P =  8.04918948393533e-17

# %% [markdown]
# <p>since the pearson coefficient is (~0.5431) the linear relationship is quite strong, and since the p-value is < 0,001 there is a strong statiscally significance </p>

# %%
#Correlation and p-value by stroke
pearson_coef_stroke, p_value_stroke = stats.pearsonr(df['stroke'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_stroke, 'with a P-vavlue of P = ', p_value_stroke)
# Out:
# The Pearson Correlation Coefficient is:  0.08226928855325809 with a P-vavlue of P =  0.2456161248774584

# %% [markdown]
# <p>since the pearson coefficient is (~0.0822) the linear relationship is weak, and since the p-value is > 0.1 there is no statistically significance evidence</p>

# %%
#Correlation and p-value by compression-ratio
pearson_coef_cr, p_value_cr = stats.pearsonr(df['compression-ratio'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_cr, 'with a P-vavlue of P = ', p_value_cr)
# Out:
# The Pearson Correlation Coefficient is:  0.0755416374691369 with a P-vavlue of P =  0.28649970076287984

# %% [markdown]
# <p>since the pearson coefficient is (~0.0755) the linear relationship is weak, and since the p-value is > 0.1 there is no statistically significance evidence</p>

# %%
#Correlation and -value by horsepower
pearson_coef_hp, p_value_hp = stats.pearsonr(df['horsepower'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_hp, 'with a P-vavlue of P = ', p_value_hp)
# Out:
# The Pearson Correlation Coefficient is:  0.8096068016571054 with a P-vavlue of P =  6.273536270650436e-48

# %% [markdown]
# <p>since the pearson coefficient is (~0.8096) the linear relationship is quite strong, and since the p-value is < 0,001 there is a strong statiscally significance </p>

# %%
#Correlation and p-value by peak-rpm
pearson_coef_p_rpm, p_value_p_rpm = stats.pearsonr(df['peak-rpm'],df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_p_rpm, 'with a P-vavlue of P = ', p_value_p_rpm)
# Out:
# The Pearson Correlation Coefficient is:  -0.10161237413760969 with a P-vavlue of P =  0.151191070667008

# %% [markdown]
# <p>since the pearson coefficient is (~-0.101) the linear relationship is negative and weak, and since the p-value is > 0.1 there is no statiscally significance evidence</p>

# %%
#Correlation and p-value by city-mpg
pearson_coef_c_mpg, p_value_c_mpg = stats.pearsonr(df['city-mpg'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_c_mpg, 'with a P-vavlue of P = ', p_value_c_mpg)
# Out:
# The Pearson Correlation Coefficient is:  -0.6865710067844678 with a P-vavlue of P =  2.321132065567512e-29

# %% [markdown]
# <p>since the pearson coefficient is (~-0.6865) the linear relationship is negative amd quite strong, and since the p-value is < 0.001 there is a strong statistically significance</p>

# %%
#correlation and p-value by highway-mpg
pearson_coef_h_mpg, p_value_h_mpg = stats.pearsonr(df['highway-mpg'], df['price'])
print('The Pearson Correlation Coefficient is: ', pearson_coef_h_mpg, 'with a P-vavlue of P = ', p_value_h_mpg)
# Out:
# The Pearson Correlation Coefficient is:  -0.704692265058953 with a P-vavlue of P =  1.7495471144475452e-31

# %% [markdown]
# <p>since the pearson coefficient is (~-0.7046) the linear relationship is negative amd quite strong, and since the p-value is < 0.001 there is a strong statistically significance</p>

# %% [markdown]
# #### Important variables

# %% [markdown]
# <p>Continuos numerical variables:</p>
# <ul>
#     <li>Length</li>
#     <li>Width</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Horsepower</li>
#     <li>City-mpg</li>
#     <li>Highway-mpg</li>
#     <li>Wheel-base</li>
#     <li>Bore</li>
# </ul>
#
# <p>Categorical variables:</p>
# <ul>
#     <li>Drive-wheels</li>
# </ul>
